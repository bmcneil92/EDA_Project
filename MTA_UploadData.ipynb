# %%
import pandas as pd
from datetime import datetime, timedelta
import sqlalchemy 
import urllib.request
import argparse
    


num_weeks = 12

#set start date
startdate = pd.Timestamp('2021-03-20 00:00:00')

config_dates = []
config_dates.append(startdate)

for week in range(num_weeks):
    startdate = config_dates[-1]
    newdate = startdate - timedelta(days=7)
#    print(newdate)
    config_dates.append(newdate)
#    print(week)


#initialise the regex for the MTA turnstile url
filename_regex = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"


#generate dates for 11 weeks
for week in config_dates:
    datetext = str(week)
    filedate_str = datetext[2:4]+datetext[5:7]+datetext[8:10]
    print(filedate_str)
    urllib.request.urlretrieve(f"http://web.mta.info/developers/data/nyct/turnstile/turnstile_{filedate_str}.txt",
                               f"Metis_Material/MTA_Project/Data/inbound/turnstile_{filedate_str}.txt")
    


#df['STATION'].value_counts()

#####
# skip header when uploading files into DB
#Terminal Reader: .mode csv
#Terminal Reader: .import meal_data.csv {tablename} ---- For MTA Project > insert files into DB.
#https://stackoverflow.com/questions/51802854/how-do-i-import-a-text-file-into-a-sqlite3-table-using-python
# Out:
# 210320
# 210313
# 210306
# 210227
# 210220
# 210213
# 210206
# 210130
# 210123
# 210116
# 210109
# 210102
# 201226

# %%
SCP, STATION, DATE
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/13/2021  03:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/13/2021  07:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/13/2021  11:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/13/2021  15:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/13/2021  19:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/13/2021  23:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/14/2021  04:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/14/2021  08:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/14/2021  12:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  03/14/2021  16:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/14/2021  20:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/15/2021  00:00:00
# ...

# %% [markdown]
# # df[(df['STATION'] == '59 ST') & (df['DATE'] == '03/14/2021') & (df['SCP']=='02-00-00')]

# %%
df.groupby(['STATION', 'SCP', 'DATE', 'ENTRIES'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1e51306a67bc> in <module>
# ----> 1 df.groupby(['STATION', 'SCP', 'DATE', 'ENTRIES'])
#       2 df
#
# NameError: name 'df' is not defined

# %%
df_test = df.groupby(['DATE'])
df_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc669855b49a> in <module>
# ----> 1 df_test = df.groupby(['DATE'])
#       2 df_test
#       3
#       4
#       5
#
# NameError: name 'df' is not defined
